# %% [markdown]
# <a href="https://colab.research.google.com/github/athulrj02/DA-Python/blob/main/20035410%7CExercise_5_PandasMerge%26Plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Week 5 Exercise: Pandas Joining, merging DataFrame and Plotting**
#
# [link text](https://colab.research.google.com/drive/1RLi-f2Hkhj9k2xVn_3fuWgXE-GFWFvPu#scrollTo=PeIvStR0MWe5)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1. Write a Pandas program to append a list of dictioneries or series to an existing DataFrame and display the combined data.
student_detail = pd.DataFrame({
    'student_id': ['S1', 'S2', 'S3', 'S4', 'S5'],
    'name': ['Danniella Fenton', 'Ryder Storey', 'Bryce Jensen', 'Ed Bernal', 'Kwame Morin'],
    'marks': [200, 210, 190, 222, 199]
})

newStudent ={
    'student_id':'S6',
    'name':'Scarlette Fisher',
    'marks':205
}
student_detail = pd.concat([student_detail, pd.DataFrame([newStudent])], ignore_index=True)
student_detail
# Out:
#   student_id              name  marks
# 0         S1  Danniella Fenton    200
# 1         S2      Ryder Storey    210
# 2         S3      Bryce Jensen    190
# 3         S4         Ed Bernal    222
# 4         S5       Kwame Morin    199
# 5         S6  Scarlette Fisher    205

# %%
#2. Write a Pandas program to join the two given dataframes a long rows and merge with another dataframe along the common column id.
student_data1 = pd.DataFrame({
    'student_id': ['S1', 'S2', 'S3', 'S4', 'S5'],
    'name': ['Danniella Fenton', 'Ryder Storey', 'Bryce Jensen', 'Ed Bernal', 'Kwame Morin'],
    'marks': [200, 210, 190, 222, 199]
})

student_data2 = pd.DataFrame({
    'student_id': ['S4', 'S5', 'S6', 'S7', 'S8'],
    'name': ['Scarlette Fisher', 'Carla Williamson', 'Dante Morse', 'Kaiser William', 'Madeeha Preston'],
    'marks': [201, 200, 198, 219, 201]
})

exam_data = pd.DataFrame({
    'student_id': ['S1', 'S2', 'S3', 'S4', 'S5', 'S7', 'S8', 'S9', 'S10', 'S11', 'S12', 'S13'],
    'exam_id': [23, 45, 12, 67, 21, 55, 33, 14, 56, 83, 88, 12]
})

combined_data = pd.concat([student_data1, student_data2])
merged_data = pd.merge(combined_data, exam_data, on='student_id')
merged_data
# Out:
#   student_id              name  marks  exam_id
# 0         S1  Danniella Fenton    200       23
# 1         S2      Ryder Storey    210       45
# 2         S3      Bryce Jensen    190       12
# 3         S4         Ed Bernal    222       67
# 4         S5       Kwame Morin    199       21
# 5         S4  Scarlette Fisher    201       67
# 6         S5  Carla Williamson    200       21
# 7         S7    Kaiser William    219       55
# 8         S8   Madeeha Preston    201       33

# %%
#3. Write a Pandas program to join the two dataframes using the common column of both dataframes.
merged_students = pd.merge(student_data1, student_data2, on="student_id", how= 'inner')
merged_students
# Out:
#   student_id       name_x  marks_x            name_y  marks_y
# 0         S4    Ed Bernal      222  Scarlette Fisher      201
# 1         S5  Kwame Morin      199  Carla Williamson      200

# %%
#4. Write a Pandas program to join the two dataframes with matching records from both sides where available.
merged_students2 = pd.merge(student_data1, student_data2, on="student_id", how = 'outer')
merged_students2
# Out:
#   student_id            name_x  marks_x            name_y  marks_y
# 0         S1  Danniella Fenton    200.0               NaN      NaN
# 1         S2      Ryder Storey    210.0               NaN      NaN
# 2         S3      Bryce Jensen    190.0               NaN      NaN
# 3         S4         Ed Bernal    222.0  Scarlette Fisher    201.0
# 4         S5       Kwame Morin    199.0  Carla Williamson    200.0
# 5         S6               NaN      NaN       Dante Morse    198.0
# 6         S7               NaN      NaN    Kaiser William    219.0
# 7         S8               NaN      NaN   Madeeha Preston    201.0

# %%
#5. Write a Pandas program to join (left join) the two dataframes using keys from left dataframe only.
data1= pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                     'P': ['P0', 'P1', 'P2', 'P3'],
                     'Q': ['Q0', 'Q1', 'Q2', 'Q3']})
data2= pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                      'key2': ['K0', 'K0', 'K0', 'K0'],
                     'R': ['R0', 'R1', 'R2', 'R3'],
                     'S': ['S0', 'S1', 'S2', 'S3']
})
left_join = pd.merge(data1, data2, on=['key1', 'key2'], how='left')
left_join
# Out:
#   key1 key2   P   Q    R    S
# 0   K0   K0  P0  Q0   R0   S0
# 1   K0   K1  P1  Q1  NaN  NaN
# 2   K1   K0  P2  Q2   R1   S1
# 3   K1   K0  P2  Q2   R2   S2
# 4   K2   K1  P3  Q3  NaN  NaN

# %%
df = pd.read_csv('alphabet_stock_data.csv')
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2020-04-01  1122.000000  1129.689941  1097.449951  1105.619995
# 1    2020-04-02  1098.260010  1126.859985  1096.400024  1120.839966
# 2    2020-04-03  1119.015015  1123.540039  1079.810059  1097.880005
# 3    2020-04-06  1138.000000  1194.660034  1130.939941  1186.920044
# 4    2020-04-07  1221.000000  1225.000000  1182.229980  1186.510010
# ..          ...          ...          ...          ...          ...
# 122  2020-09-24  1411.030029  1443.708984  1409.849976  1428.290039
# 123  2020-09-25  1432.630005  1450.000000  1413.339966  1444.959961
# 124  2020-09-28  1474.209961  1476.800049  1449.301025  1464.520020
# 125  2020-09-29  1470.390015  1476.662964  1458.805054  1469.329956
# 126  2020-09-30  1466.800049  1489.750000  1459.880005  1469.599976
#
#        Adj Close   Volume
# 0    1105.619995  2343100
# 1    1120.839966  1964900
# 2    1097.880005  2313400
# 3    1186.920044  2664700
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# %%
# 6. Write a Pandas program to create a line plot of the historical stock prices of Alphabet Inc. between two specific dates.
startDate, endDate = '2020-04-01', '2020-06-30'

plt.figure(figsize=(10, 6))
df['Close'].loc[startDate:endDate].plot(kind='line')
plt.title('Historical Stock Prices, Alphabet Inc.')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.grid(True)
plt.show()

# %%
# 7. Write a Pandas program to create a line plot of the opening, closing stock prices of Alphabet Inc. between two specific dates.
plt.figure(figsize= (10,6))
df[['Open','Close']].loc[startDate:endDate].plot(kind='line')
plt.title('Opening, Closing Stock Prices, Alphabet Inc.')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend(['Open', 'Close'])
plt.grid(True)
plt.grid(True)
plt.show()

# %%
# 8. Write a Pandas program to create a bar plot of the trading volume of Alphabet Inc. stock between two specific dates.
plt.figure(figsize=(10, 6))
df['Volume'].loc[startDate:endDate].plot(kind='bar')
plt.title('Trading Volume, Alphabet Inc.')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# 9. Write a Pandas program to create a bar plot of opening, closing stock prices of Alphabet Inc. between two specific dates.
plt.figure(figsize=(10, 6))
df[['Open', 'Close']].loc[startDate:endDate].plot(kind='bar')
plt.title('Opening, Closing Stock Prices, Alphabet Inc.')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend(['Open', 'Close'])
# plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# 10.Write a Pandas program to create a stacked bar plot of opening, closing stock prices of Alphabet Inc. between two specific dates.
plt.figure(figsize=(10,6))
df[['Open','Close']].loc[startDate:endDate].plot(kind='bar',stacked=True)
plt.title('Opening, Closing Stock Prices, Alphabet Inc.')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend(['Open','Close'])
# plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
