# %% [markdown]
# <a href="https://colab.research.google.com/github/athulrj02/DA-Python/blob/main/20035410%7CExercise6_VisualisationIrisDataSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Exercise 6: Visualisation of the Iris Data Set

# 5. Create a boxplot over the four dimensions
# 6. Implement a function that creates a scatter plot matrix, where the main diagonal are
# either boxplots or histograms and classes.
# 7. Encode the class information with different colors in the scatter plot matrix

# %%
# 1. load the Iris data set
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
iris = datasets.load_iris()

# %%
df = iris.data
feature_names = iris.feature_names
feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
# 2. Create a single histogram-plot for every dimension using matplotlib
plt.figure(figsize=(10,6))
plt.subplot(2,2,1)
plt.hist(x[:,0])
plt.title(feature_names[0])

plt.subplot(2,2,2)
plt.hist(x[:,1])
plt.title(feature_names[1])

plt.subplot(2,2,3)
plt.hist(x[:,2])
plt.title(feature_names[2])

plt.subplot(2,2,4)
plt.hist(x[:,3])
plt.title(feature_names[3])

plt.tight_layout()
plt.show()

# %%
# 3. Create a 4x4 plot containing the four histograms side by side
plt.figure(figsize=(10,6))
plt.hist(df[:, 0], alpha = 0.5, label = feature_names[0])
plt.hist(df[:, 1], alpha = 0.5, label = feature_names[1])
plt.hist(df[:, 2], alpha = 0.5, label = feature_names[2])
plt.hist(df[:, 3], alpha = 0.5, label = feature_names[3])
plt.legend()
plt.title('Iris 4x4 Histograms')
plt.show()

# %%
# 4. Create a single histogram-plot containing all dimensions
plt.figure(figsize=(10,6))
plt.boxplot(df)
plt.xticks([1,2,3,4], feature_names, rotation = 45)
plt.title('Iris Boxplot')
plt.show()
